# %%
# Imports

import pandas as pd
from numpy import mean
from numpy import std
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
import math
from filterpicker import filterpicker as FP

# %%
file_test = pd.read_csv(r'..\wetransfer_resend-gmr-data_2021-10-25_0710\NGA_csv_horizontal\375-E.AT2.csv', low_memory=False)
#print (file_test)

df = file_test.copy()
df.set_axis(["time", "acceleration"],axis=1,inplace=True)

#df1 = df
#df1 = df1[df1.time > 8.656]
#df1 = df1[df1.time < 14]

#print(df1)

# %%
#plt.plot(file_test)

df.plot(x="time", y="aceleration",figsize=(20, 10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\tese\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\tese\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\tese\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'aceleration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [149], in <cell line: 3>()
#       1 #plt.plot(file_test)
# ----> 3 df.plot(x="time", y="aceleration",figsize=(20, 10))
#       4 plt.show()
#
# File ~\anaconda3\envs\tese\lib\site-packages\pandas\plotting\_core.py:958, in PlotAccessor.__call__(self, *args, **kwargs)
#     955             pass
#     957 # don't overwrite
# --> 958 data = data[y].copy()
#     960 if isinstance(data, ABCSeries):
#     961     label_name = label_kw or y
#
# File ~\anaconda3\envs\tese\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\tese\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'aceleration'

# %%
fpp = FP.FilterPicker(0.008, df.acceleration, filter_window=1.6, longterm_window=3.2, t_up=0.16,threshold_1=20, threshold_2=10)
pidx, punc, pfrq = fpp.run()
print(pidx, punc, pfrq)
fpp.plot()


#print(df.time[200])
#print(df.time[400])
# Out:
# [8.296 8.656] [0.016 0.008] [5. 2.]
# C:\Users\lisac\anaconda3\envs\tese\lib\site-packages\filterpicker\filterpicker.py:331: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()
# ) missing from current font.s\tese\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)
# (<Figure size 720x504 with 8 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        dtype=object))

# %%
##### Mag 5 #####

file_test_5 = pd.read_csv(r'./Renamed_Records/AM-1990-0013.csv', low_memory=False)
#print (file_test)

df5 = file_test_5.copy()
df5.set_axis(["time", "acceleration"],axis=1,inplace=True)

df5.plot(x="time", y="acceleration",figsize=(20, 10))
plt.show()

fpp5 = FP.FilterPicker(0.008, df5.acceleration, filter_window=1.6, longterm_window=3.2, t_up=0.16,threshold_1=20, threshold_2=10)
pidx5, punc5, pfrq5 = fpp5.run()
print(pidx5, punc5, pfrq5)
fpp5.plot()
# Out:
# [6.552] [0.024] [2.]
# ) missing from current font.s\tese\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)
# (<Figure size 720x504 with 8 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        dtype=object))

# %%
##### Mag 6 #####

# 

file_test_6 = pd.read_csv(r'./Renamed_Records/EMSC-20100411_0000035.csv', low_memory=False)
#print (file_test)

df6 = file_test_5.copy()
df6.set_axis(["time", "acceleration"],axis=1,inplace=True)
df6.head()

fpp6 = FP.FilterPicker(0.008, df6.acceleration, filter_window=1.6, longterm_window=3.2, t_up=0.16,threshold_1=20, threshold_2=10)
pidx6, punc6, pfrq6 = fpp6.run()
print(pidx6, punc6, pfrq6)
fpp6.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       1 ##### Mag 6 #####
#       2
#       3 #
# ----> 5 file_test_6 = pd.read_csv(r'./Renamed_Records/EMSC-20100411_0000035.csv', low_memory=False)
#       6 #print (file_test)
#       8 df6 = file_test_5.copy()
#
# NameError: name 'pd' is not defined
